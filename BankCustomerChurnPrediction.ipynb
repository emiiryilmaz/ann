# %%
#Emir Yılmaz 190101025
#Esra Özdemir 190101040
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/Churn_Modelling.csv")

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(8,8))
sns.countplot(x='Exited', data=df)
plt.xlabel('0: Customers still with the bank, 1: Customers exited the bank')
plt.ylabel('Count')
plt.title('Bank Customers Churn Visualization')
plt.show()

# %%
corr_matrix = df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# <ipython-input-12-930bc3e201a0>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
numeric_features = ['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'EstimatedSalary']
df[numeric_features].hist(bins=30, figsize=(12, 8))
plt.show()

# %%
categorical_features = ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember', 'Exited']
for feature in categorical_features:
    sns.countplot(x=feature, data=df)
    plt.show()

# %%
df.isna().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
df.drop(['RowNumber','CustomerId','Surname'], axis=1, inplace=True)
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %%
geography = pd.get_dummies(df['Geography'], drop_first=True)
gender = pd.get_dummies(df['Gender'], drop_first=True)

# %%
df = pd.concat([df, geography, gender], axis=1)
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited', 'Germany', 'Spain', 'Male'],
#       dtype='object')

# %%
df.drop(['Geography', 'Gender'], axis=1, inplace=True)

# %%
X = df.drop('Exited', axis=1)
y = df['Exited']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
print('X_train size: {}, X_test size: {}'.format(X_train.shape, X_test.shape))
# Out:
# X_train size: (8000, 11), X_test size: (2000, 11)

# %%
X_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 7389          667   34       5       0.00              2          1
# 9275          427   42       1   75681.52              1          1
# 2995          535   29       2  112367.34              1          1
# 5316          654   40       5  105683.63              1          1
# 356           850   57       8  126776.30              2          1
# ...           ...  ...     ...        ...            ...        ...
# 9225          594   32       4  120074.97              2          1
# 4859          794   22       4  114440.24              1          1
# 3264          738   35       5  161274.05              2          1
# 9845          590   38       9       0.00              2          1
# 2732          623   48       1  108076.33              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 7389               0        163830.64        0      1     0
# 9275               1         57098.00        1      0     1
# 2995               0        185630.76        0      0     0
# 5316               0        173617.09        0      1     1
# 356                1        132298.49        0      1     0
# ...              ...              ...      ...    ...   ...
# 9225               1        162961.79        1      0     0
# 4859               1        107753.07        0      1     0
# 3264               0        181429.87        0      0     1
# 9845               1        148750.16        0      1     0
# 2732               0        118855.26        1      0     0
#
# [8000 rows x 11 columns]

# %%
y_train
# Out:
# 7389    0
# 9275    0
# 2995    0
# 5316    0
# 356     0
#        ..
# 9225    0
# 4859    0
# 3264    0
# 9845    0
# 2732    1
# Name: Exited, Length: 8000, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu', input_dim=11))

# %%
classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu'))

# %%
classifier.add(Dense(units=1, kernel_initializer='glorot_uniform', activation='sigmoid'))

# %%
import tensorflow as tf

# %%
classifier.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                   loss='binary_crossentropy',
                   metrics=['accuracy'])

# %%
model_history = classifier.fit(X_train, y_train, batch_size=10, validation_data=(X_test, y_test), epochs=100)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 3s 2ms/step - loss: 0.5007 - accuracy: 0.7839 - val_loss: 0.4471 - val_accuracy: 0.7980
# Epoch 2/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4378 - accuracy: 0.8071 - val_loss: 0.4236 - val_accuracy: 0.8120
# Epoch 3/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4214 - accuracy: 0.8119 - val_loss: 0.4163 - val_accuracy: 0.8240
# Epoch 4/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.4135 - accuracy: 0.8140 - val_loss: 0.4100 - val_accuracy: 0.8255
# Epoch 5/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.4058 - accuracy: 0.8164 - val_loss: 0.4017 - val_accuracy: 0.8320
# Epoch 6/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3982 - accuracy: 0.8207 - val_loss: 0.3939 - val_accuracy: 0.8335
# Epoch 7/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3904 - accuracy: 0.8246 - val_loss: 0.3855 - val_accuracy: 0.8350
# Epoch 8/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3822 - accuracy: 0.8316 - val_loss: 0.3794 - val_accuracy: 0.8360
# Epoch 9/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3748 - accuracy: 0.8359 - val_loss: 0.3719 - val_accuracy: 0.8385
# Epoch 10/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3680 - accuracy: 0.8425 - val_loss: 0.3637 - val_accuracy: 0.8480
# Epoch 11/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3637 - accuracy: 0.8504 - val_loss: 0.3610 - val_accuracy: 0.8505
# Epoch 12/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3607 - accuracy: 0.8510 - val_loss: 0.3570 - val_accuracy: 0.8520
# Epoch 13/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3590 - accuracy: 0.8501 - val_loss: 0.3573 - val_accuracy: 0.8525
# Epoch 14/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3569 - accuracy: 0.8522 - val_loss: 0.3536 - val_accuracy: 0.8515
# Epoch 15/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3558 - accuracy: 0.8531 - val_loss: 0.3546 - val_accuracy: 0.8535
# Epoch 16/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3549 - accuracy: 0.8533 - val_loss: 0.3514 - val_accuracy: 0.8515
# Epoch 17/100
# 800/800 [==============================] - 3s 4ms/step - loss: 0.3540 - accuracy: 0.8537 - val_loss: 0.3527 - val_accuracy: 0.8480
# Epoch 18/100
# 800/800 [==============================] - 4s 4ms/step - loss: 0.3523 - accuracy: 0.8555 - val_loss: 0.3507 - val_accuracy: 0.8530
# Epoch 19/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3515 - accuracy: 0.8550 - val_loss: 0.3492 - val_accuracy: 0.8550
# Epoch 20/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3507 - accuracy: 0.8546 - val_loss: 0.3484 - val_accuracy: 0.8535
# Epoch 21/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3500 - accuracy: 0.8565 - val_loss: 0.3461 - val_accuracy: 0.8540
# Epoch 22/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3490 - accuracy: 0.8569 - val_loss: 0.3450 - val_accuracy: 0.8525
# Epoch 23/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3476 - accuracy: 0.8566 - val_loss: 0.3485 - val_accuracy: 0.8495
# Epoch 24/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3467 - accuracy: 0.8574 - val_loss: 0.3443 - val_accuracy: 0.8550
# Epoch 25/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3457 - accuracy: 0.8575 - val_loss: 0.3421 - val_accuracy: 0.8580
# Epoch 26/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3454 - accuracy: 0.8575 - val_loss: 0.3454 - val_accuracy: 0.8550
# Epoch 27/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.
100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3321 - accuracy: 0.8664 - val_loss: 0.3350 - val_accuracy: 0.8670
# Epoch 88/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3320 - accuracy: 0.8637 - val_loss: 0.3351 - val_accuracy: 0.8675
# Epoch 89/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3315 - accuracy: 0.8664 - val_loss: 0.3421 - val_accuracy: 0.8560
# Epoch 90/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3313 - accuracy: 0.8676 - val_loss: 0.3350 - val_accuracy: 0.8630
# Epoch 91/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3313 - accuracy: 0.8637 - val_loss: 0.3356 - val_accuracy: 0.8635
# Epoch 92/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3313 - accuracy: 0.8645 - val_loss: 0.3348 - val_accuracy: 0.8660
# Epoch 93/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3315 - accuracy: 0.8665 - val_loss: 0.3377 - val_accuracy: 0.8610
# Epoch 94/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3318 - accuracy: 0.8645 - val_loss: 0.3349 - val_accuracy: 0.8650
# Epoch 95/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3318 - accuracy: 0.8662 - val_loss: 0.3365 - val_accuracy: 0.8630
# Epoch 96/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3315 - accuracy: 0.8645 - val_loss: 0.3347 - val_accuracy: 0.8645
# Epoch 97/100
# 800/800 [==============================] - 2s 3ms/step - loss: 0.3310 - accuracy: 0.8666 - val_loss: 0.3343 - val_accuracy: 0.8645
# Epoch 98/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3312 - accuracy: 0.8660 - val_loss: 0.3341 - val_accuracy: 0.8655
# Epoch 99/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3313 - accuracy: 0.8644 - val_loss: 0.3333 - val_accuracy: 0.8685
# Epoch 100/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3309 - accuracy: 0.8634 - val_loss: 0.3388 - val_accuracy: 0.8660

# %%
model_history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure(figsize=(8,8))
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower right')
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %%
y_pred = classifier.predict(X_test)
# Out:
# 63/63 [==============================] - 0s 2ms/step

# %%
y_pred
# Out:
# array([[0.19922918],
#        [0.3554497 ],
#        [0.15301183],
#        ...,
#        [0.12408949],
#        [0.15250719],
#        [0.21294202]], dtype=float32)

# %%
y_pred = (y_pred > 0.5)
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1519,   76],
#        [ 192,  213]])

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False,
            annot_kws={"size": 14}, linewidths=0.5, square=True)

plt.xlabel("Predicted", fontsize=14)
plt.ylabel("Actual", fontsize=14)
plt.title("Confusion Matrix", fontsize=16)
plt.show()

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred,y_test)
print('The accuracy for ANN model is: {}%'.format(score*100))
# Out:
# The accuracy for ANN model is: 86.6%

# %%
def predict_exit(sample_value):

  sample_value = np.array(sample_value)

  sample_value = sample_value.reshape(1, -1)

  sample_value = sc.transform(sample_value)

  return classifier.predict(sample_value)

# %%
sample_value = [738, 62, 10, 83008.31, 1, 1, 1, 42766.03, 1, 0, 1]
if predict_exit(sample_value)>0.5:
  print('Prediction: High change of exit!')
else:
  print('Prediction: Low change of exit.')
# Out:
# 1/1 [==============================] - 0s 29ms/step
# Prediction: Low change of exit.
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
sample_value = [805, 45, 9, 116585.97, 1, 1, 0, 189428.75, 1, 0, 0]
if predict_exit(sample_value)>0.5:
  print('Prediction: High change of exit!')
else:
  print('Prediction: Low change of exit.')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 29ms/step
# Prediction: High change of exit!

# %%
from keras.models import load_model

# %%
classifier.save('model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
loaded_model = load_model('model.h5')
